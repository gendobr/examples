# %%
# install Owlready2 package
# !pip install Owlready2
# Out:
# Collecting Owlready2
#   Downloading https://files.pythonhosted.org/packages/13/1d/d9efef926bddd80923196b20ca7ea433642de78d253784e73ce1cc22600e/Owlready2-0.21.tar.gz (20.0MB)
# Building wheels for collected packages: Owlready2
#   Building wheel for Owlready2 (setup.py): started
#   Building wheel for Owlready2 (setup.py): finished with status 'done'
#   Created wheel for Owlready2: filename=Owlready2-0.21-cp37-cp37m-win_amd64.whl size=19776644 sha256=95c9c4dd2142598927cb0c9e4d14e3459ec1d5d87805395c9683de7b63158570
#   Stored in directory: C:\Users\dobrovolskyi_h\AppData\Local\pip\Cache\wheels\10\fd\59\e35a4545fff96706a24ebf02bf5ba2f9da772c88d66d05b03b
# Successfully built Owlready2
# Installing collected packages: Owlready2
# Successfully installed Owlready2-0.21
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# load ontology
from owlready2 import *

# set cache path
onto_path.append("./pizza")

# load owl file
onto = get_ontology("./pizza/pizza.owl")

onto.load()
# Out:
# get_ontology("http://www.co-ode.org/ontologies/pizza/")

# %%
# get namespace
pizza = onto.get_namespace('http://www.co-ode.org/ontologies/pizza/pizza.owl')

# %%
sync_reasoner()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp c:\users\dobrovolskyi_h\appdata\local\programs\python\python37\lib\site-packages\owlready2\hermit;c:\users\dobrovolskyi_h\appdata\local\programs\python\python37\lib\site-packages\owlready2\hermit\HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:///C:/Users/DOBROV~1/AppData/Local/Temp/tmp4opnmneg
# * Owlready2 * HermiT took 1.9177260398864746 seconds
# * Owlready * Reparenting pizza.isToppingOf: {owl.ObjectProperty, owl.FunctionalProperty, pizza.isIngredientOf} => {pizza.isIngredientOf, owl.FunctionalProperty}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
"""
Show list of classes
"""
list(onto.classes())
# Out:
# [pizza.Pizza,
#  pizza.PizzaBase,
#  pizza.Food,
#  pizza.Spiciness,
#  pizza.PizzaTopping,
#  pizza.American,
#  pizza.NamedPizza,
#  pizza.MozzarellaTopping,
#  pizza.PeperoniSausageTopping,
#  pizza.TomatoTopping,
#  pizza.AmericanHot,
#  pizza.HotGreenPepperTopping,
#  pizza.JalapenoPepperTopping,
#  pizza.AnchoviesTopping,
#  pizza.FishTopping,
#  pizza.ArtichokeTopping,
#  pizza.VegetableTopping,
#  pizza.Mild,
#  pizza.AsparagusTopping,
#  pizza.Cajun,
#  pizza.OnionTopping,
#  pizza.PeperonataTopping,
#  pizza.PrawnsTopping,
#  pizza.TobascoPepperSauce,
#  pizza.CajunSpiceTopping,
#  pizza.HerbSpiceTopping,
#  pizza.Hot,
#  pizza.RosemaryTopping,
#  pizza.CaperTopping,
#  pizza.Capricciosa,
#  pizza.HamTopping,
#  pizza.OliveTopping,
#  pizza.Caprina,
#  pizza.GoatsCheeseTopping,
#  pizza.SundriedTomatoTopping,
#  pizza.CheeseTopping,
#  pizza.CheeseyPizza,
#  pizza.CheeseyVegetableTopping,
#  pizza.ChickenTopping,
#  pizza.MeatTopping,
#  pizza.Country,
#  pizza.DomainConcept,
#  pizza.DeepPanBase,
#  pizza.ThinAndCrispyBase,
#  pizza.ValuePartition,
#  pizza.Fiorentina,
#  pizza.GarlicTopping,
#  pizza.ParmesanTopping,
#  pizza.SpinachTopping,
#  pizza.FourCheesesTopping,
#  pizza.FourSeasons,
#  pizza.MushroomTopping,
#  pizza.FruitTopping,
#  pizza.FruttiDiMare,
#  pizza.MixedSeafoodTopping,
#  pizza.Medium,
#  pizza.Giardiniera,
#  pizza.LeekTopping,
#  pizza.PetitPoisTopping,
#  pizza.SlicedTomatoTopping,
#  pizza.GorgonzolaTopping,
#  pizza.GreenPepperTopping,
#  pizza.PepperTopping,
#  pizza.HotSpicedBeefTopping,
#  pizza.IceCream,
#  pizza.InterestingPizza,
#  pizza.LaReine,
#  pizza.Margherita,
#  pizza.MeatyPizza,
#  pizza.Mushroom,
#  pizza.Napoletana,
#  pizza.NonVegetarianPizza,
#  pizza.VegetarianPizza,
#  pizza.NutTopping,
#  pizza.ParmaHamTopping,
#  pizza.Parmense,
#  pizza.PineKernels,
#  pizza.PolloAdAstra,
#  pizza.RedOnionTopping,
#  pizza.SweetPepperTopping,
#  pizza.PrinceCarlo,
#  pizza.QuattroFormaggi,
#  pizza.RealItalianPizza,
#  pizza.RocketTopping,
#  pizza.Rosa,
#  pizza.SauceTopping,
#  pizza.Siciliana,
#  pizza.SloppyGiuseppe,
#  pizza.Soho,
#  pizza.SpicyPizza,
#  pizza.SpicyTopping,
#  pizza.SpicyPizzaEquivalent,
#  pizza.SultanaTopping,
#  pizza.ThinAndCrispyPizza,
#  pizza.UnclosedPizza,
#  pizza.VegetarianPizzaEquivalent1,
#  pizza.VegetarianTopping,
#  pizza.VegetarianPizzaEquivalent2,
#  pizza.Veneziana]

# %%
"""
Show list of properties
"""
list(onto.properties())
# Out:
# [pizza.hasBase,
#  pizza.hasIngredient,
#  pizza.isBaseOf,
#  pizza.hasCountryOfOrigin,
#  pizza.isIngredientOf,
#  pizza.hasSpiciness,
#  pizza.hasTopping,
#  pizza.isToppingOf,
#  1.1.title,
#  terms.contributor,
#  terms.license,
#  terms.provenance,
#  1.1.description,
#  core.altLabel,
#  core.definition,
#  core.prefLabel]

# %%
"""
Search by IRI
"""

onto.search(iri = "*Topping")
# Out:
# [pizza.hasTopping, pizza.PizzaTopping, pizza.MozzarellaTopping, pizza.PeperoniSausageTopping, pizza.TomatoTopping, pizza.HotGreenPepperTopping, pizza.JalapenoPepperTopping, pizza.AnchoviesTopping, pizza.FishTopping, pizza.ArtichokeTopping, pizza.VegetableTopping, pizza.AsparagusTopping, pizza.OnionTopping, pizza.PeperonataTopping, pizza.PrawnsTopping, pizza.CajunSpiceTopping, pizza.HerbSpiceTopping, pizza.RosemaryTopping, pizza.CaperTopping, pizza.HamTopping, pizza.OliveTopping, pizza.GoatsCheeseTopping, pizza.SundriedTomatoTopping, pizza.CheeseTopping, pizza.CheeseyVegetableTopping, pizza.ChickenTopping, pizza.MeatTopping, pizza.GarlicTopping, pizza.ParmesanTopping, pizza.SpinachTopping, pizza.FourCheesesTopping, pizza.MushroomTopping, pizza.FruitTopping, pizza.MixedSeafoodTopping, pizza.LeekTopping, pizza.PetitPoisTopping, pizza.SlicedTomatoTopping, pizza.GorgonzolaTopping, pizza.GreenPepperTopping, pizza.PepperTopping, pizza.HotSpicedBeefTopping, pizza.NutTopping, pizza.ParmaHamTopping, pizza.RedOnionTopping, pizza.SweetPepperTopping, pizza.RocketTopping, pizza.SauceTopping, pizza.SpicyTopping, pizza.SultanaTopping, pizza.VegetarianTopping]

# %%
pizza.Pizza.descendants()
# Out:
# {pizza.American,
#  pizza.AmericanHot,
#  pizza.Cajun,
#  pizza.Capricciosa,
#  pizza.Caprina,
#  pizza.CheeseyPizza,
#  pizza.Fiorentina,
#  pizza.FourSeasons,
#  pizza.FruttiDiMare,
#  pizza.Giardiniera,
#  pizza.InterestingPizza,
#  pizza.LaReine,
#  pizza.Margherita,
#  pizza.MeatyPizza,
#  pizza.Mushroom,
#  pizza.NamedPizza,
#  pizza.Napoletana,
#  pizza.NonVegetarianPizza,
#  pizza.Parmense,
#  pizza.Pizza,
#  pizza.PolloAdAstra,
#  pizza.PrinceCarlo,
#  pizza.QuattroFormaggi,
#  pizza.RealItalianPizza,
#  pizza.Rosa,
#  pizza.Siciliana,
#  pizza.SloppyGiuseppe,
#  pizza.Soho,
#  pizza.SpicyPizza,
#  pizza.SpicyPizzaEquivalent,
#  pizza.ThinAndCrispyPizza,
#  pizza.UnclosedPizza,
#  pizza.VegetarianPizza,
#  pizza.VegetarianPizzaEquivalent1,
#  pizza.VegetarianPizzaEquivalent2,
#  pizza.Veneziana}

# %%
list(onto.disjoint_classes())
# Out:
# [AllDisjoint([pizza.IceCream, pizza.Pizza, pizza.PizzaBase, pizza.PizzaTopping]),
#  AllDisjoint([pizza.Hot, pizza.Medium, pizza.Mild]),
#  AllDisjoint([pizza.GreenPepperTopping, pizza.JalapenoPepperTopping, pizza.PeperonataTopping, pizza.SweetPepperTopping]),
#  AllDisjoint([pizza.FourCheesesTopping, pizza.GoatsCheeseTopping, pizza.GorgonzolaTopping, pizza.MozzarellaTopping, pizza.ParmesanTopping]),
#  AllDisjoint([pizza.ChickenTopping, pizza.HamTopping, pizza.HotSpicedBeefTopping, pizza.PeperoniSausageTopping]),
#  AllDisjoint([pizza.CheeseTopping, pizza.FishTopping, pizza.FruitTopping, pizza.HerbSpiceTopping, pizza.MeatTopping, pizza.NutTopping, pizza.SauceTopping, pizza.VegetableTopping]),
#  AllDisjoint([pizza.ArtichokeTopping, pizza.AsparagusTopping, pizza.CaperTopping, pizza.GarlicTopping, pizza.LeekTopping, pizza.MushroomTopping, pizza.OliveTopping, pizza.OnionTopping, pizza.PepperTopping, pizza.PetitPoisTopping, pizza.RocketTopping, pizza.SpinachTopping, pizza.TomatoTopping]),
#  AllDisjoint([pizza.AnchoviesTopping, pizza.MixedSeafoodTopping, pizza.PrawnsTopping]),
#  AllDisjoint([pizza.American, pizza.AmericanHot, pizza.Cajun, pizza.Capricciosa, pizza.Caprina, pizza.Fiorentina, pizza.FourSeasons, pizza.FruttiDiMare, pizza.Giardiniera, pizza.LaReine, pizza.Margherita, pizza.Mushroom, pizza.Napoletana, pizza.Parmense, pizza.PolloAdAstra, pizza.PrinceCarlo, pizza.QuattroFormaggi, pizza.Rosa, pizza.Siciliana, pizza.SloppyGiuseppe, pizza.Soho, pizza.UnclosedPizza, pizza.Veneziana]),
#  AllDisjoint([pizza.CajunSpiceTopping, pizza.RosemaryTopping]),
#  AllDisjoint([pizza.DeepPanBase, pizza.ThinAndCrispyBase]),
#  AllDisjoint([pizza.DomainConcept, pizza.ValuePartition]),
#  AllDisjoint([pizza.NonVegetarianPizza, pizza.VegetarianPizza]),
#  AllDisjoint([pizza.SlicedTomatoTopping, pizza.SundriedTomatoTopping])]

# %%
list(onto.different_individuals() )
# Out:
# [AllDisjoint([pizza.America, pizza.England, pizza.France, pizza.Germany, pizza.Italy])]

# %%
"""
install rdflib
"""

# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading https://files.pythonhosted.org/packages/3c/fe/630bacb652680f6d481b9febbb3e2c3869194a1a5fc3401a4a41195a2f8f/rdflib-4.2.2-py3-none-any.whl (344kB)
# Requirement already satisfied: pyparsing in c:\users\dobrovolskyi_h\appdata\local\programs\python\python37\lib\site-packages (from rdflib) (2.3.0)
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Requirement already satisfied: six in c:\users\dobrovolskyi_h\appdata\local\programs\python\python37\lib\site-packages (from isodate->rdflib) (1.12.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.0 rdflib-4.2.2

# %%
# construct SPARQL executor
graph = default_world.as_rdflib_graph()

# %%
"""
Run simple query that shows properties of the class NamedPizza
# ?s                ?p                 ?o
rdf:about         some property      object
"""
list(graph.query("""
SELECT ?p ?o WHERE {
  <http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza> ?p ?o .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#   rdflib.term.Literal('A pizza that can be found on a pizza menu', lang='en')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('PizzaComUmNome', lang='pt'))]

# %%
"""
Define xml namespaces
and run the same query
"""

list(graph.query("""
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX owl:<http://www.w3.org/2002/07/owl#>
PREFIX xml:<http://www.w3.org/XML/1998/namespace>
PREFIX xsd:<http://www.w3.org/2001/XMLSchema#>
PREFIX skos:<http://www.w3.org/2004/02/skos/core#>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX dc:<http://purl.org/dc/elements/1.1/>
SELECT ?p ?o WHERE {
  pizza:NamedPizza ?p ?o .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#   rdflib.term.Literal('A pizza that can be found on a pizza menu', lang='en')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('PizzaComUmNome', lang='pt'))]

# %%
"""
Query for class - direct_subclass relations
"""
list(graph.query("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?s ?o WHERE {
  # ?s rdfs:subClassOf ?o .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.BNode('1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.BNode('2')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.BNode('3')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.BNode('4')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.BNode('9')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('10')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('11')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('12')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('13')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('14')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('15')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.BNode('22')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AnchoviesTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ArtichokeTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ArtichokeTopping'),
#   rdflib.term.BNode('23')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AsparagusTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AsparagusTopping'),
#   rdflib.term.BNode('24')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('25')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('26')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('27')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('28')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('29')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('30')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.BNode('31')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CajunSpiceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HerbSpiceTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CajunSpiceTopping'),
#   rdflib.term.BNode('39')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CaperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CaperTopping'),
#   rdflib.term.BNode('40')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('41')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('42')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('43')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('44')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('45')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('46')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('47')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.BNode('48')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.BNode('57')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.BNode('58')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.BNode('59')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.BNode('60')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.BNode('61')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyVegetableTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyVegetableTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ChickenTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ChickenTopping'),
#   rdflib.term.BNode('71')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#DeepPanBase'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaBase')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('81')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('82')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('83')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('84')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('85')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('86')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.BNode('87')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping'),
#   rdflib.term.BNode('95')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#DomainConcept')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourCheesesTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourCheesesTopping'),
#   rdflib.term.BNode('96')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('97')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('98')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('99')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('100')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('101')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('102')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('103')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.BNode('104')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruitTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.BNode('113')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.BNode('114')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.BNode('115')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.BNode('116')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GarlicTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GarlicTopping'),
#   rdflib.term.BNode('121')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('122')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('123')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('124')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('125')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('126')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('127')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('128')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('129')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.BNode('130')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GoatsCheeseTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GoatsCheeseTopping'),
#   rdflib.term.BNode('140')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GorgonzolaTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GorgonzolaTopping'),
#   rdflib.term.BNode('141')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GreenPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HamTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HerbSpiceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Hot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Spiciness')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotGreenPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GreenPepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotGreenPepperTopping'),
#   rdflib.term.BNode('142')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotSpicedBeefTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotSpicedBeefTopping'),
#   rdflib.term.BNode('143')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#IceCream'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#IceCream'),
#   rdflib.term.BNode('144')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#JalapenoPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#JalapenoPepperTopping'),
#   rdflib.term.BNode('149')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('150')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('151')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('152')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('153')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('154')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.BNode('155')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LeekTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LeekTopping'),
#   rdflib.term.BNode('162')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.BNode('163')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.BNode('164')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.BNode('165')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Medium'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Spiciness')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mild'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Spiciness')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MixedSeafoodTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MozzarellaTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MozzarellaTopping'),
#   rdflib.term.BNode('173')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MozzarellaTopping'),
#   rdflib.term.BNode('174')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.BNode('175')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.BNode('176')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.BNode('177')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.BNode('178')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MushroomTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MushroomTopping'),
#   rdflib.term.BNode('183')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('184')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('185')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('186')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('187')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('188')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('189')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.BNode('196')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NutTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NutTopping'),
#   rdflib.term.BNode('201')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OliveTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OliveTopping'),
#   rdflib.term.BNode('202')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OnionTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OnionTopping'),
#   rdflib.term.BNode('203')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmaHamTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HamTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmaHamTopping'),
#   rdflib.term.BNode('204')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('205')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('206')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('207')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('208')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('209')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.BNode('210')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmesanTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmesanTopping'),
#   rdflib.term.BNode('217')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperonataTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperonataTopping'),
#   rdflib.term.BNode('218')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperoniSausageTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperoniSausageTopping'),
#   rdflib.term.BNode('219')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PetitPoisTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PetitPoisTopping'),
#   rdflib.term.BNode('220')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PineKernels'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NutTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza'),
#   rdflib.term.BNode('221')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaBase'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('222')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('223')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('224')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('225')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('226')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('227')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('228')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.BNode('229')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrawnsTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('238')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('239')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('240')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('241')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('242')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.BNode('243')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.BNode('250')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.BNode('251')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.BNode('252')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza'),
#   rdflib.term.BNode('260')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RedOnionTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OnionTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RocketTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RocketTopping'),
#   rdflib.term.BNode('261')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.BNode('262')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.BNode('263')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.BNode('264')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.BNode('265')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RosemaryTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HerbSpiceTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RosemaryTopping'),
#   rdflib.term.BNode('270')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SauceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('271')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('272')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('273')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('274')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('275')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('276')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('277')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.BNode('278')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SlicedTomatoTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SlicedTomatoTopping'),
#   rdflib.term.BNode('287')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('288')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('289')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('290')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('291')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('292')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.BNode('293')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('300')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('301')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('302')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('303')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('304')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('305')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.BNode('306')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Spiciness'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ValuePartition')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpinachTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpinachTopping'),
#   rdflib.term.BNode('334')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SultanaTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruitTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SultanaTopping'),
#   rdflib.term.BNode('335')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SundriedTomatoTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SundriedTomatoTopping'),
#   rdflib.term.BNode('336')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SweetPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SweetPepperTopping'),
#   rdflib.term.BNode('337')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyBase'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaBase')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TobascoPepperSauce'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SauceTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TobascoPepperSauce'),
#   rdflib.term.BNode('342')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping'),
#   rdflib.term.BNode('343')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza'),
#   rdflib.term.BNode('344')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('378')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('379')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('380')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('381')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('382')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('383')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('384')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('385')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.BNode('394')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotGreenPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CajunSpiceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TobascoPepperSauce'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#JalapenoPepperTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HotSpicedBeefTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Country'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#DomainConcept')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#HerbSpiceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruitTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NutTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SauceTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping'),
#   rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping'))]

# %%
"""
Look for all pizza names
"""
list(graph.query("""
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>
PREFIX owl:<http://www.w3.org/2002/07/owl#>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
SELECT ?s  WHERE {
  # ?s rdfs:subClassOf pizza:NamedPizza .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana'))]

# %%
"""
Search all pizza descendants
"""
list(graph.query("""
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>

SELECT ?s  WHERE {
  # ?s rdfs:subClassOf* pizza:Pizza .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza'))]

# %%
"""
Search 
"""
list(graph.query("""
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>

SELECT ?s  WHERE {
  # ?s rdfs:subClassOf pizza:VegetableTopping .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#ArtichokeTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AsparagusTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OnionTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CaperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#OliveTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyVegetableTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#GarlicTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SpinachTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#MushroomTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LeekTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PetitPoisTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#RocketTopping'))]

# %%
"""
Show all pizzas that have topping
"""
list(graph.query("""
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>

select distinct ?p where {
  # ?p rdfs:subClassOf [
      a owl:Restriction;
      owl:onProperty pizza:hasTopping
  ] .
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#IceCream')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'))]

# %%
"""
Extend previous query with requirement "pizza should have vegetable topping"
"""
list(graph.query("""
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX pizza:<http://www.co-ode.org/ontologies/pizza/pizza.owl#>
select DISTINCT ?p where {
  # ?p rdfs:subClassOf [
      a owl:Restriction;
      owl:onProperty pizza:hasTopping;
      owl:someValuesFrom ?t
  ] .
  # ?t rdfs:subClassOf pizza:VegetableTopping
}"""))
# Out:
# [(rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot')),
#  (rdflib.term.URIRef('http://www.co-ode.org/ontologies/pizza/pizza.owl#American'))]
